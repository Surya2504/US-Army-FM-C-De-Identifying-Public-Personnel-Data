# %%
# %matplotlib inline

import altair as alt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns;
import pandas as pd
import os
from scipy import stats
from scipy.stats import pearsonr
sns.set(color_codes=True)
import statsmodels.api as sm  
from statsmodels.formula.api import ols
from sklearn import linear_model

# %%
Records= pd.read_table('FEC092021/DTagy.txt')
Records
# Out:
#      AGYTYP                                            AGYTYPT AGY  \
# 0         1                             Cabinet Level Agencies  AF
# 1         1                             Cabinet Level Agencies  AF
# 2         1                             Cabinet Level Agencies  AF
# 3         1                             Cabinet Level Agencies  AF
# 4         1                             Cabinet Level Agencies  AF
# ..      ...                                                ...  ..
# 532       4  Small Independent Agencies (less than 100 empl...  WX
# 533       4  Small Independent Agencies (less than 100 empl...  ZL
# 534       4  Small Independent Agencies (less than 100 empl...  ZP
# 535       4  Small Independent Agencies (less than 100 empl...  ZS
# 536       4  Small Independent Agencies (less than 100 empl...  ZU
#
#                                                   AGYT AGYSUB  \
# 0                       AF-DEPARTMENT OF THE AIR FORCE   AF02
# 1                       AF-DEPARTMENT OF THE AIR FORCE   AF03
# 2                       AF-DEPARTMENT OF THE AIR FORCE   AF06
# 3                       AF-DEPARTMENT OF THE AIR FORCE   AF07
# 4                       AF-DEPARTMENT OF THE AIR FORCE   AF09
# ..                                                 ...    ...
# 532               WX-WORLD WAR 1 CENTENNIAL COMMISSION   WX00
# 533            ZL-MEDICARE PAYMENT ADVISORY COMMISSION   ZL00
# 534  ZP-U.S. COMMISSION ON INTERNATIONAL RELIGIOUS ...   ZP00
# 535  ZS-UNITED STATES-CHINA ECONOMIC AND SECURITY R...   ZS00
# 536        ZU-DWIGHT D. EISENHOWER MEMORIAL COMMISSION   ZU00
#
#                                                AGYSUBT
# 0                AF02-AIR FORCE INSPECTION AGENCY (FO)
# 1    AF03-AIR FORCE OPERATIONAL TEST AND EVALUATION...
# 2                          AF06-AIR FORCE AUDIT AGENCY
# 3      AF07-AIR FORCE OFFICE OF SPECIAL INVESTIGATIONS
# 4                      AF09-AIR FORCE PERSONNEL CENTER
# ..                                                 ...
# 532             WX00-WORLD WAR 1 CENTENNIAL COMMISSION
# 533          ZL00-MEDICARE PAYMENT ADVISORY COMMISSION
# 534  ZP00-U.S. COMMISSION ON INTERNATIONAL RELIGIOU...
# 535  ZS00-UNITED STATES-CHINA ECONOMIC AND SECURITY...
# 536      ZU00-DWIGHT D. EISENHOWER MEMORIAL COMMISSION
#
# [537 rows x 6 columns]
