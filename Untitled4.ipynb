# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importing September data using pandas
df1 = pd.read_csv("C:/D/COurses/DAEN 690/dataset/FedScope Employment Cube (September 2021)/FACTDATA_SEP2021.TXT")
# Importing June data using pandas
df2 = pd.read_csv("C:/D/COurses/DAEN 690/dataset/FedScope Employment Cube (June 2021)/FACTDATA_JUN2021.TXT")
#merge data of both Sep and June using pandas
# Out:
# C:\Users\veena\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3,4,6,8,12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1.head()
# Out:
#   AGYSUB LOC AGELVL EDLVL GSEGRD LOSLVL   OCC  PATCO  PP  PPGRD SALLVL  \
# 0   AA00  11      F    13    NaN      F  0340      2  ES  ES-**      S
# 1   AA00  11      I    15    NaN      H  0905      1  ES  ES-**      R
# 2   AA00  11      E    15   15.0      E  0905      1  99  GS-15      Q
# 3   AA00  11      E    15   15.0      E  0905      1  99  GS-15      N
# 4   AA00  11      F    15   13.0      E  0905      1  99  GS-13      K
#
#   STEMOCC SUPERVIS TOA WORKSCH  WORKSTAT  DATECODE  EMPLOYMENT    SALARY   LOS
# 0    XXXX        2  50       F         1    202109           1  192500.0  18.3
# 1    XXXX        2  50       F         1    202109           1  187000.0  28.7
# 2    XXXX        2  30       F         1    202109           1  172500.0  12.0
# 3    XXXX        8  30       F         1    202109           1  144128.0  10.0
# 4    XXXX        8  30       F         1    202109           1  114059.0  12.9

# %%
df2.head()
# Out:
#   AGYSUB LOC AGELVL EDLVL GSEGRD LOSLVL  OCC  PATCO  PP  PPGRD SALLVL STEMOCC  \
# 0   AA00  11      F    13    NaN      F  340      2  ES  ES-**      R    XXXX
# 1   AA00  11      I    15    NaN      H  905      1  ES  ES-**      R    XXXX
# 2   AA00  11      E    15   15.0      E  905      1  99  GS-15      Q    XXXX
# 3   AA00  11      D    15   15.0      D  905      1  99  GS-15      N    XXXX
# 4   AA00  11      F    15   13.0      E  905      1  99  GS-13      K    XXXX
#
#   SUPERVIS TOA WORKSCH  WORKSTAT  DATECODE  EMPLOYMENT    SALARY   LOS
# 0        2  50       F         1    202106           1  181500.0  18.0
# 1        2  50       F         1    202106           1  181500.0  28.4
# 2        2  30       F         1    202106           1  172500.0  11.8
# 3        8  30       F         1    202106           1  144128.0   9.8
# 4        8  30       F         1    202106           1  114059.0  12.7

# %%
pip install datacompy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import datacompy

# %%
compare = datacompy.Compare(
df1,
df2,
join_columns='AGYSUB', #You can also specify a list of columns
abs_tol=0.0001,
rel_tol=0,
df1_name='sep',
df2_name='june')

# %%
print(compare.report())
# Out:
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#   DataFrame  Columns     Rows
# 0       sep       20  2191011
# 1      june       20  2188923
#
# Column Summary
# --------------
#
# Number of columns in common: 20
# Number of columns in sep but not in june: 0
# Number of columns in june but not in sep: 0
#
# Row Summary
# -----------
#
# Matched on: agysub
# Any duplicates on match values: Yes
# Absolute Tolerance: 0.0001
# Relative Tolerance: 0
# Number of rows in common: 2,168,832
# Number of rows in sep but not in june: 22,179
# Number of rows in june but not in sep: 20,091
#
# Number of rows with some compared columns unequal: 2,168,832
# Number of rows with all compared columns equal: 0
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 18
# Number of columns compared with all values equal: 2
# Total number of values which compare unequal: 22,950,764
#
# ...

# %%
df1_unq = print(compare.df1_unq_rows.drop_duplicates(subset=['agysub']))
# Out:
#         agysub loc agelvl edlvl gsegrd loslvl   occ  patco  pp  ppgrd sallvl  \
# 11        AA00  11      B    13    9.0      A  0560    2.0  99  GS-09      F
# 1829      AF07  US      E    17   13.0      A  1811    2.0  99  GS-13      I
# 42757     AF13  51      J    10   12.0      E  2210    2.0  99  GS-12      I
# 42810     AF16  10      H    04    9.0      D   301    2.0  99  GS-09      E
# 134009    AF1M  06      D    08    NaN      C  6501    6.0  99  WG-08      E
# ...        ...  ..    ...   ...    ...    ...   ...    ...  ..    ...    ...
# 1780042   VAKA  11      E    13    NaN      E   301    2.0  99  EX-04      O
# 1806503   VAPA  11      E    17   12.0      F  0301    2.0  99  GS-12      I
# 2189479   VATA  21      I    13    6.0      D  0679    4.0  99  GS-06      D
# 2190977   ZP00  11      D    17    NaN      A  0301    2.0  99  AD-00      G
# 2191009   ZS00  11      C    04    NaN      A  0301    2.0  99  AD-00      D
#
# ...

# %%
df2_unq = print(compare.df2_unq_rows.drop_duplicates(subset=['agysub']))
# Out:
#         agysub loc agelvl edlvl gsegrd loslvl   occ  patco  pp  ppgrd sallvl  \
# 2191011   AB00  FR      F    17   13.0      E  1001    2.0  99  GS-13      H
# 2191013   AF02  35      C    17   13.0      B  1515    1.0  99  GS-13      I
# 2191015   AF03  35      B    04    3.0      A   399    5.0  99  GS-03      B
# 2191026   AF06  KS      E    17   12.0      E   511    1.0  99  GS-12      G
# 2191030   AF09  48      G    13   13.0      D   201    2.0  99  GS-13      I
# ...        ...  ..    ...   ...    ...    ...   ...    ...  ..    ...    ...
# 2210896   VALA  53      E    13   10.0      E  0996    2.0  99  GS-10      G
# 2211095   VD00  11      D    04    NaN      A  0905    1.0  99  AD-00      J
# 2211097   WK00  27      E    07   14.0      A  0301    2.0  99  GS-14      N
# 2211099   ZL00  11      K    04    NaN      B  0301    2.0  99  SR-00      Q
# 2211100   ZU00  11      E    17    NaN      D  0301    2.0  99  AD-00      K
#
# ...

# %%
print(compare.intersect_rows)
# Out:
#         agysub loc_df1 agelvl_df1 edlvl_df1 gsegrd_df1 loslvl_df1 occ_df1  \
# 0         AA00      11          F        13        NaN          F    0340
# 1         AA00      11          I        15        NaN          H    0905
# 2         AA00      11          E        15       15.0          E    0905
# 3         AA00      11          E        15       15.0          E    0905
# 4         AA00      11          F        15       13.0          E    0905
# ...        ...     ...        ...       ...        ...        ...     ...
# 2191005   ZS00      11          C        17        NaN          A    0301
# 2191006   ZS00      11          I        01        NaN          A    0301
# 2191007   ZS00      11          C        17        NaN          A    0301
# 2191008   ZS00      11          D        04        NaN          B    0301
# 2191010   ZU00      11          K        17        NaN          E    0301
#
#          patco_df1 pp_df1 ppgrd_df1  ... sallvl_match stemocc_match  \
# ...
